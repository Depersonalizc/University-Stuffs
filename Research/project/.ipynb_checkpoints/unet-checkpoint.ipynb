# %%
from data_builder import DataBuilder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4e6ae516078e> in <module>
# ----> 1 from data_builder import DataBuilder
#
# ModuleNotFoundError: No module named 'data_builder'

# %%
data_builder = DataBuilder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c56beecb8418> in <module>
# ----> 1 data_builder = DataBuilder()
#
# NameError: name 'DataBuilder' is not defined

# %%
data_builder.load_training_data('H:/data/example.pt')

# %%
data_builder.show_data_point(11777)

# %% [markdown]
# #
